# %% [markdown]
# # Introduction

# %%
import numpy as numpy
import pandas as pd
import re

# %% [markdown]
# # Examining the data frame

# %%
perscore_df = pd.read_csv("personality_scores.csv" , delimiter = ";")
perscore_df.head(5)
# Out:
#    ID Section 5 of 6 [I am always prepared.]  \
# 0   0                                 (3, 5)
# 1   1                                 (3, 5)
# 2   2                                 (3, 5)
# 3   3                                 (3, 5)
# 4   4                                 (3, 3)
#
#   Section 5 of 6 [I am easily disturbed.]  \
# 0                                  (4, 5)
# 1                                  (4, 5)
# 2                                  (4, 3)
# 3                                  (4, 5)
# 4                                  (4, 5)
#
#   Section 5 of 6 [I am exacting (demanding) in my work.]  \
# 0                                             (3, 5)
# 1                                             (3, 5)
# 2                                             (3, 3)
# 3                                             (3, 3)
# 4                                             (3, 3)
#
#   Section 5 of 6 [I am full of ideas.]  \
# 0                               (5, 5)
# ...

# %% [markdown]
# # Checking Missing values

# %%
perscore_df.isnull().sum()
# Out:
# ID                                                           0
# Section 5 of 6 [I am always prepared.]                       0
# Section 5 of 6 [I am easily disturbed.]                      0
# Section 5 of 6 [I am exacting (demanding) in my work.]       0
# Section 5 of 6 [I am full of ideas.]                         0
#                                                           ...
# Unnamed: 65                                               1555
# Unnamed: 66                                               1555
# Unnamed: 67                                               1555
# Unnamed: 68                                               1555
# IPIP_HIGH_RISK                                            1555
# Length: 70, dtype: int64

# %% [markdown]
# # Checking for duplicates

# %%
#Checking the number of unique values
perscore_unique = perscore_df["ID"].nunique()
perscore_unique
# Out:
# 1555

# %% [markdown]
# There are 1555 unique values in the ID meaning that there are no duplicates in the ID of the dataframe

# %% [markdown]
# # Removing duplicates

# %%
for score in perscore_df:
    if "ID" in perscore_df:
        new_df = perscore_df.drop_duplicates(subset = ["ID"], keep = "first", inplace = False)

# %% [markdown]
# # Dropping unnecessary columns

# %%
#Dropping Unnamed: column from data frame because it has null values
new_df.dropna(axis = 1,inplace = True)
new_df.head(5)
# Out:
#    ID Section 5 of 6 [I am always prepared.]  \
# 0   0                                 (3, 5)
# 1   1                                 (3, 5)
# 2   2                                 (3, 5)
# 3   3                                 (3, 5)
# 4   4                                 (3, 3)
#
#   Section 5 of 6 [I am easily disturbed.]  \
# 0                                  (4, 5)
# 1                                  (4, 5)
# 2                                  (4, 3)
# 3                                  (4, 5)
# 4                                  (4, 5)
#
#   Section 5 of 6 [I am exacting (demanding) in my work.]  \
# 0                                             (3, 5)
# 1                                             (3, 5)
# 2                                             (3, 3)
# 3                                             (3, 3)
# 4                                             (3, 3)
#
#   Section 5 of 6 [I am full of ideas.]  \
# 0                               (5, 5)
# ...

# %% [markdown]
# # Renaming my dataframe to remove regular expressions

# %%
new_df.rename(columns = {"Section 5 of 6 [I am always prepared.]": "I am always prepared"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I am easily disturbed.]": "I am easily disturbed"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I am exacting (demanding) in my work.]": "I am exacting (demanding) in my work"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I am full of ideas.]": "I am full of ideas"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I am interested in people.]": "I am interested in people"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I am always prepared.]": "I am always prepared"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I am easily disturbed.]": "I am easily disturbed"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I am exacting (demanding) in my work.]": "I am exacting (demanding) in my work"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I am full of ideas.]": "I am full of ideas"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I am interested in people.]": "I am interested in people"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I am not interested in abstract ideas.]": "I am not interested in abstract ideas."}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I am not interested in other people's problems.]": "I am not interested in other people's problems"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I am not really interested in others.]": "I am not really interested in others"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I am quick to understand things.]": "I am quick to understand things"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I am quiet around strangers.]": "I am quiet around strangers"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I pay attention to details.]": "I pay attention to details"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I seldom feel blue (down).]": "I seldom feel blue (down)"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I spend time reflecting on things.]": "I spend time reflecting on things"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I start conversations.]": "I start conversations"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I sympathize with others' feelings.]": "I sympathize with others' feelings"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I take time out for others.]": "I take time out for others"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I talk to a lot of different people at parties.]": "I talk to a lot of different people at parties"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I use difficult words.]": "I use difficult words"}, inplace = True)
new_df.rename(columns = {"Section 5 of 6 [I worry about things.]": "I worry about things"}, inplace = True)

new_df.head(5)
# Out:
#    ID I am always prepared I am easily disturbed  \
# 0   0               (3, 5)                (4, 5)
# 1   1               (3, 5)                (4, 5)
# 2   2               (3, 5)                (4, 3)
# 3   3               (3, 5)                (4, 5)
# 4   4               (3, 3)                (4, 5)
#
#   I am exacting (demanding) in my work I am full of ideas  \
# 0                               (3, 5)             (5, 5)
# 1                               (3, 5)             (5, 5)
# 2                               (3, 3)             (5, 5)
# 3                               (3, 3)             (5, 5)
# 4                               (3, 3)             (5, 3)
#
#   I am interested in people I am not interested in abstract ideas.  \
# 0                    (2, 3)                                 (5, 3)
# 1                    (2, 5)                                 (5, 3)
# 2                    (2, 5)                                 (5, 5)
# ...

# %% [markdown]
# # Setting the ID column to be the index of the dataframe

# %%
per_index = new_df.set_index("ID")
per_index.head(5)
# Out:
#    I am always prepared I am easily disturbed  \
# ID
# 0                (3, 5)                (4, 5)
# 1                (3, 5)                (4, 5)
# 2                (3, 5)                (4, 3)
# 3                (3, 5)                (4, 5)
# 4                (3, 3)                (4, 5)
#
#    I am exacting (demanding) in my work I am full of ideas  \
# ID
# 0                                (3, 5)             (5, 5)
# 1                                (3, 5)             (5, 5)
# 2                                (3, 3)             (5, 5)
# 3                                (3, 3)             (5, 5)
# 4                                (3, 3)             (5, 3)
#
#    I am interested in people I am not interested in abstract ideas.  \
# ID
# 0                     (2, 3)                                 (5, 3)
# 1                     (2, 5)                                 (5, 3)
# 2                     (2, 5)                                 (5, 5)
# ...

# %% [markdown]
# # Checking is new data frame == original dataframe and asserting new data frame with original dataframe

# %%
if  len(perscore_df) == len(new_df):
    print(True)
else:
    print(False)
# Out:
# True

# %%
assert len(perscore_df) == len(new_df)

# %% [markdown]
# # Calculating total score
